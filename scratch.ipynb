# %%
import os

import polars as pl

import sys
sys.path.append("/Users/evanappel/Documents")
for i in sys.path:
    print(i)
from feynman.ask import Ask as ask
import main
import __init__ as variables
# Out:
# /usr/local/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python313.zip
# /usr/local/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13
# /usr/local/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload
#
# /Users/evanappel/elvis/.venv/lib/python3.13/site-packages
# /Users/evanappel/Documents

# %%
lff:pl.LazyFrame = main.SNHD_INSPECTIONS()

# %%
df:pl.DataFrame = lff.collect()

# %%
print(df.schema)

# %%
snowflake_lf =
